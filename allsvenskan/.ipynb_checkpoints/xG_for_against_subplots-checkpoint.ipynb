# %%
# import required libraries
import os
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mplsoccer import Pitch, VerticalPitch
import matplotlib_inline
from matplotlib import cm
import matplotlib_inline
import seaborn as sns
#matplotlib_inline.backend_inline.set_matplotlib_formats('svg')

# %%
df = pd.read_csv("merged_match_results.csv")

# %%
df.head()
# Out:
#    wk        date   time         home  homegoals              away  awaygoals  \
# 0   1  2021-04-10  15:00     Malmö FF          3          Hammarby          2
# 1   1  2021-04-10  17:30       Örebro          0      IFK Göteborg          0
# 2   1  2021-04-11  15:00     Halmstad          1         BK Häcken          0
# 3   1  2021-04-11  15:00  Mjällby AIF          0  Varbergs BoIS FC          0
# 4   1  2021-04-11  17:30  IF Elfsborg          0        Djurgården          2
#
#     home_xg   away_xg  home_pen_xg  away_pen_xg  home_np_xg  away_np_xg
# 0  3.081973  0.284890     0.725091          0.0    2.356882    0.284890
# 1  0.630045  0.747871     0.000000          0.0    0.630045    0.747871
# 2  1.014930  0.405163     0.000000          0.0    1.014930    0.405163
# 3  1.517195  0.707990     0.000000          0.0    1.517195    0.707990
# 4  0.841527  0.221132     0.000000          0.0    0.841527    0.221132

# %%
df.shape
# Out:
# (240, 13)

# %%
df['home'].unique()
# Out:
# array(['Malmö FF', 'Örebro', 'Halmstad', 'Mjällby AIF', 'IF Elfsborg',
#        'IFK Norrköping FK', 'AIK', 'Kalmar FF', 'Hammarby',
#        'Degerfors IF', 'Östersund', 'BK Häcken', 'Djurgården',
#        'IK Sirius FK', 'IFK Göteborg', 'Varbergs BoIS FC'], dtype=object)

# %%
team_color = {'Malmö FF':['white', 'skyblue'], 
              'AIK':['darkblue', 'yellow'],  
              'Djurgården':['skyblue', 'darkblue'], 
              'IF Elfsborg':['yellow', 'black'], 
              'Hammarby':['white', 'darkgreen'],
              'Kalmar FF':['red', 'white'], 
              'IFK Norrköping FK':['white', 'blue'], 
              'IFK Göteborg':['blue', 'skyblue'], 
              'Mjällby AIF':['#FCDF51', 'black'],
              'Varbergs BoIS FC':['#53B663', 'black'], 
              'IK Sirius FK':['blue', 'black'], 
              'BK Häcken':['black', '#FFF275'], 
              'Degerfors IF':['red', 'white'],
              'Halmstad':['blue', 'black'], 
              'Örebro':['white', 'black'], 
              'Östersund':['red', 'black']}

# %%
team_ranks = ['Malmö FF', 'AIK', 'Djurgården', 'IF Elfsborg', 'Hammarby',
'Kalmar FF', 'IFK Norrköping FK', 'IFK Göteborg', 'Mjällby AIF',
'Varbergs BoIS FC', 'IK Sirius FK', 'BK Häcken', 'Degerfors IF',
'Halmstad', 'Örebro', 'Östersund']

# %%
fig, ax = plt.subplots(nrows = 4, ncols = 4, figsize = (12, 12))

fig.set_facecolor("white")

ind = 0
for i in range(4):
    for j in range(4):
        # grid settings
        ax[i, j].grid(color='black', ls = '-.', lw = 0.25)

        # face color of axis and figure
        ax[i, j].set_facecolor("white")

        # plotting data 
        team_df = df[(df['home'] == team_ranks[ind]) | (df['away'] == team_ranks[ind])]
        ax[i, j].scatter(df['home_np_xg'], df['away_np_xg'], c = 'gray', alpha = 0.2, s = 50)
        ax[i, j].scatter(team_df['home_np_xg'], team_df['away_np_xg'], s = 100, c = team_color[team_ranks[ind]][0], 
                         edgecolor = team_color[team_ranks[ind]][1])

        # set limit for x and y axis
        ax[i, j].set_xlim(0, 7)
        ax[i, j].set_ylim(0, 7)

        # remove tick lines from both axis
        #ax.xaxis.set_tick_params(length = 0)
        #ax.yaxis.set_tick_params(length = 0)
        ax[i, j].tick_params(length = 0)

        # remove '0' on y-axis
        ax[i, j].yaxis.get_major_ticks()[0].label1.set_visible(False)

        # plot dashed line 
        x = np.array([0, 7])
        y = np.array([0, 7])
        ax[i, j].plot(x, y, c = 'gray', ls = '--', lw = 1)

        # font dictionary
        font3 = {'family': 'monospace', 'weight': 'bold', 'size': 14}
        # axis labels
        ax[i, j].set_xlabel('xG Against')
        ax[i, j].set_ylabel('xG')
        ax[i, j].set_title(team_ranks[ind], loc = 'left')

        # update index for list of teams
        ind = ind + 1
plt.tight_layout()
plt.show()
fig.savefig('xg_subplots.png', dpi = 300, transparent = False)
